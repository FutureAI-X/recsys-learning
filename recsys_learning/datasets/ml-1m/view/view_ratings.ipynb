# %%
import pandas as pd

# %%
ratings_raw_file = "/mnt/workspace/recsys-learning/recsys_learning/datasets/ml-1m/raw/ratings.dat"

# %%
ratings_raw_data = pd.read_csv(ratings_raw_file, sep="::", names=["UserID", "MovieID", "Rating", "Timestamp"])
ratings_raw_data
# Out:
# /tmp/ipykernel_3151/3167247904.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings_raw_data = pd.read_csv(ratings_raw_file, sep="::", names=["UserID", "MovieID", "Rating", "Timestamp"])
#          UserID  MovieID  Rating  Timestamp
# 0             1     1193       5  978300760
# 1             1      661       3  978302109
# 2             1      914       3  978301968
# 3             1     3408       4  978300275
# 4             1     2355       5  978824291
# ...         ...      ...     ...        ...
# 1000204    6040     1091       1  956716541
# 1000205    6040     1094       5  956704887
# 1000206    6040      562       5  956704746
# 1000207    6040     1096       4  956715648
# 1000208    6040     1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
user_id_nunique = ratings_raw_data["UserID"].nunique()
print(f"用户数：{user_id_nunique}")
# Out:
# 用户数：6040

# %%
movie_id_nunique = ratings_raw_data["MovieID"].nunique()
print(f"电影数：{movie_id_nunique}")
# Out:
# 电影数：3706

# %%
rating_count = ratings_raw_data["Rating"].value_counts()
print("评分分布情况")
rating_count
# Out:
# 评分分布情况
# Rating
# 4    348971
# 3    261197
# 5    226310
# 2    107557
# 1     56174
# Name: count, dtype: int64
