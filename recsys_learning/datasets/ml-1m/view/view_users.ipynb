# %%
import pandas as pd

# %%
users_raw_file = "/mnt/workspace/recsys-learning/recsys_learning/datasets/ml-1m/raw/users.dat"

# %%
users_raw_data = pd.read_csv(users_raw_file, sep="::", names=["UserID", "Gender", "Age", "Occupation", "Zip-code"])
users_raw_data
# Out:
# /tmp/ipykernel_1953/357945673.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users_raw_data = pd.read_csv(users_raw_file, sep="::", names=["UserID", "Gender", "Age", "Occupation", "Zip-code"])
#       UserID Gender  Age  Occupation Zip-code
# 0          1      F    1          10    48067
# 1          2      M   56          16    70072
# 2          3      M   25          15    55117
# 3          4      M   45           7    02460
# 4          5      M   25          20    55455
# ...      ...    ...  ...         ...      ...
# 6035    6036      F   25          15    32603
# 6036    6037      F   45           1    76006
# 6037    6038      F   56           1    14706
# 6038    6039      F   45           0    01060
# 6039    6040      M   25           6    11106
#
# ...
